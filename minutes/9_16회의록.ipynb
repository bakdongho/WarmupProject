# %% [markdown]
# ## 9/16 회의록
#
# ### 1. 화상회의 (9:00)
#
# #### 결과
# 이희진 : 태그를 이용해서 클러스터를 하였으나, 활용이 안될거 같아 중단
#
# 최재현 : 레시피 페이지를 자바스크립트로 60% 구현
#
# 서예지 : 리뷰데이터 크롤링
#
# 유세빈 & 박동호 : 전체 구조도 설계 및 추가 기능 고안
#
# => 장고기반 웹서비스를 프로토타입을 만들어보자. 3명은 웹 구조 / 2명은 모델고민
#
# #### 다음 목표
# 이희진 : 질병에 좋지 않은 재료를 필터하고 영양소 위주 추천 구현
#
# 최재현 : 장고를 이용하여 웹 구조 설계
#
# 서예지 : 리뷰데이터를 이용하여
#
# 유세빈 : 누락 기능 연동 및 장고 이용 구조 설계
#
# 박동호 : 구조 설계 / 모델링 설계 고민
#
#
# ### 2. 화상회의 (17:20)
#
# #### 결과
# 이희진 : 해먹남녀의 재료 데이터 정제가 너무 안되있어서 안좋은 재료로 필터가 의미가 없는 것 같다. => 데이터 전처리를 할려 했으나 너무 어려웠고 의미가 없었다. / 태그로 클러스터링 시도하였는데 괜찮았다.
#
# 서예지 : 리뷰데이터 크롤링에 어려움이 많아 시범으로 1000개 정도만 뽑아와서 음식명과 리뷰로 훈련을 시켜서 리뷰를 넣으면 음식이 나오게 했으나 결과가 아쉬움. 해먹남녀 데이터로는 요리법과 태그를 넣어 보았으나 의미가 애매함. 모델을 사용한 것에 의의를 둠.
#
# 유세빈 : 데이터 DB화 장고로 웹 연동
#
# #### 다음 목표
# 이희진 : 질병에 좋은 재료를 필터하고 영양소 위주 추천 기능 구현
#
# 서예지 : 딥러닝 모델을 이용해서 재료를 넣었을 때 음식명이 나오게 해보기
#
# 유세빈 & 최재현 : 장고를 이용하여 웹 구조 설계 기능 연동
#
# 박동호 : 문제점 같이 고민, 웹 또는 모델링 도움
